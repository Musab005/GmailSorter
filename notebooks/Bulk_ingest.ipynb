# %%
# !git clone https://github.com/Musab005/GmailSorter.git
# Out:
# Cloning into 'GmailSorter'...
# remote: Enumerating objects: 316, done.
# remote: Counting objects: 100% (316/316), done.
# remote: Compressing objects: 100% (214/214), done.
# remote: Total 316 (delta 163), reused 243 (delta 94), pack-reused 0 (from 0)
# Receiving objects: 100% (316/316), 1.11 MiB | 11.97 MiB/s, done.
# Resolving deltas: 100% (163/163), done.

# %%
# !pip install -q -r /content/GmailSorter/requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement pywin32==311 (from versions: none)
# ERROR: No matching distribution found for pywin32==311

# %%
# !pip install dateparser dotenv chromadb
# Out:
# ...
#   Using cached dateparser-1.2.2-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached chromadb-1.0.15-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# ...
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# ...
#   Using cached posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached onnxruntime-1.22.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# ...
#   Using cached PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# ...
#   Using cached kubernetes-33.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# ...
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# ...

# %% [markdown]
# 1) Upload credentials folder from local directory
#
# 2) Upload src/global_store.py from local directory
#
# 3) Upload BERT_model from local directory
#
# 4) Change calls to config.py with userdata.get('secretName') in bulk_ingest.py and email_parser.py

# %%
# %cd /content/GmailSorter

from cognitive_inbox.scripts.bulk_ingest import run_bulk_ingestion

run_bulk_ingestion()
# Out:
# /content/GmailSorter
# ...
# FATAL ERROR: OPENAI_API_KEY is not set in the .env file.
# --- Starting Bulk Email Ingestion ---
#
# [Step 1/5] Initializing services and models...
# Gmail service successfully created.
# Fetching Gmail label mapping...
# Successfully fetched 74 labels.
# Loading custom embedding model...
# Using device: cuda
# Connecting to vector store...
# Successfully connected to ChromaDB. Collection 'gmail_embeddings' is ready.
# Initialization complete.
#
# [Step 2/5] Fetching all email IDs from your inbox...
# Found a total of 10478 message IDs.
# Found 10478 total emails to process.
#
# [Step 3/5] Parsing, chunking, embedding, and storing emails...
#
# --- Processing batch 1/210 ---
# Generating embeddings for 303 chunks...
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# ...

# %%
# !zip -r chroma_db.zip /content/GmailSorter/chroma_db
# Out:
#   adding: content/GmailSorter/chroma_db/ (stored 0%)
#   adding: content/GmailSorter/chroma_db/chroma.sqlite3 (deflated 56%)
#   adding: content/GmailSorter/chroma_db/d97004b7-3619-4354-8f77-3db99ca46658/ (stored 0%)
#   adding: content/GmailSorter/chroma_db/d97004b7-3619-4354-8f77-3db99ca46658/index_metadata.pickle (deflated 56%)
#   adding: content/GmailSorter/chroma_db/d97004b7-3619-4354-8f77-3db99ca46658/header.bin (deflated 55%)
#   adding: content/GmailSorter/chroma_db/d97004b7-3619-4354-8f77-3db99ca46658/length.bin (deflated 81%)
#   adding: content/GmailSorter/chroma_db/d97004b7-3619-4354-8f77-3db99ca46658/link_lists.bin (deflated 81%)
#   adding: content/GmailSorter/chroma_db/d97004b7-3619-4354-8f77-3db99ca46658/data_level0.bin (deflated 11%)
